# %%
import tensorflow as tf
from tensorflow import keras

import matplotlib.pyplot as plt
import numpy as np
import sys
import pandas as pd
import cv2 as cv
from sklearn.model_selection import train_test_split
import os

# %%
df = pd.read_json("images/otsu-mask/train.json")

# %%
df
# Out:
#                                           imagePath  numberOfBoxes  box1-x1  \
# 0       images/regular/flir_20200812T140059_reg.jpg              1      103
# 1       images/regular/flir_20200812T141247_reg.jpg              1      188
# 2       images/regular/flir_20200812T200542_reg.jpg              1        0
# 3       images/regular/flir_20200812T140824_reg.jpg              1        0
# 4   images/regular/flir_20200809T141533_neg_reg.jpg              0        0
# ..                                              ...            ...      ...
# 91      images/regular/flir_20200812T200517_reg.jpg              2        0
# 92  images/regular/flir_20200809T141454_neg_reg.jpg              0        0
# 93  images/regular/flir_20200812T140550_neg_reg.jpg              0        0
# 94      images/regular/flir_20200716T170540_reg.jpg              1        0
# 95  images/regular/flir_20200812T140557_neg_reg.jpg              0        0
#
# ...

# %%
augImgPath = 'images/augment'

# %%
augFileName = 'flir_20200716T164851_aug_neg_shift_rotate_flip_0_61.jpg'

# %%
for image in df.imagePath:
    base = os.path.basename(str(image))
    imageFileName = os.path.splitext(base)[0]
    print(imageFileName.split('_')[1] in augFileName)
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
